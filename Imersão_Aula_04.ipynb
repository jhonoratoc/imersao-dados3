# %% [markdown]
# <a href="https://colab.research.google.com/github/jhonoratoc/imersao-dados3/blob/main/Imers%C3%A3o_Aula_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 01

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 877 columns]

# %% [markdown]
# Como a base de dados é extensa, vamos usar o comando "head" para melhorar a visualização, mostrando apenas os 5 primeiros resultados:

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Vamos usar o comando "shape" para visualizarmos a quantidade de linhas e colunas:

# %%
dados.shape
# Out:
# (23814, 877)

# %% [markdown]
# Repare que ele já mostra ali pra gente o número de colunas: 877. Ou seja, é um dataset bem extenso.
#
# Vamos começar a analisar as colunas. A primeria coluna tem o nome de "id", o que nos remete a um identificador. Além disso, as seguintes colunas com nomes bem complexos. Não são nomes muito descritivos para quem não é da área.
#
# Com a ajuda da Vanessa, especialista, descobrimos que esses nomes remetem aos mecanismos de ação das drogas. Ou seja, esses dados nos trazem a relação do mecanismo de ação do alvo(enzima, proteína, etc) com a droga utilizada. Ela também explicou sobre os termos "agonista" e antiagonista", que ativam o receptor e o bloqueiam, resspectivamente.
#
# Nesse ponto a Vanessa nos explica numa apresentação como funciona a ligação do spike com o receptor e todo o procedimento de infecção nas nossas células.
#
# Agora já sabemos que cada coluna do nosso dataframe representa um mecanismo de ação. Olhando para nosso cabeçalho percebemos que temos praticamente todos os dados com o valor 0. Será que todos os dados da tabela tem esse valor? Vamos investigar!
#
# Vamos escolher uma coluna para investigar os seus dados.

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# #Aula 02

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 877 columns]

# %%
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
#
# [3235 rows x 877 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 compostos')
plt.show()

# %%
len(dados['g-0'].unique())
# Out:
# 14367

# %%
dados['g-0'].min()
# Out:
# -5.513

# %%
dados['g-0'].max()
# Out:
# 10.0

# %%
dados['g-0'].hist(bins = 100)

# %%
dados['g-19'].hist(bins = 100)

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g-0', 'g-1']]
# Out:
#           g-0     g-1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:,'g-0':'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:,'g-0':'g-771'].describe().T['mean'].hist(bins=30)

# %%
dados.loc[:,'g-0':'g-771'].describe().T['min'].hist(bins=30)

# %%
dados.loc[:,'g-0':'g-771'].describe().T['max'].hist(bins=30)

# %%
dados.loc[:,'c-0':'c-99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x='g-0' , data=dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='g-0', x='tratamento' , data=dados)

# %% [markdown]
# #Aula 03

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], values=dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[['g-0', 'g-3']]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g-0', y = 'g-3', data=dados)

# %%
sns.scatterplot(x='g-0', y = 'g-8', data=dados)

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color': 'red'})

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color': 'red'}, col='tratamento', row='tempo')

# %%
dados.loc[:,'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
corr = dados.loc[:,'g-0':'g-50'].corr()

# %%
import numpy as np


# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c-0':'c-50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# #Aula 4

# %% [markdown]
# *  Documentação
#   *   pandas.DataFrame.select_dtypes https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.select_dtypes.html
#
#   *   pandas.DataFrame.drop https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html
#
#   *   pandas.DataFrame.merge https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html
#
#   *   Merge, join, concatenate and compare https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#
# *   Desafios
#   *   pandas.Series.str.split https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html
#   *   pandas.DataFrame.reset_index https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html

# %% [markdown]
# Olá cientista!
#
# Seja bem vindo e bem vinda à aula 04!
#
# Na aula passada, exploramos a relação e a correlação entre nossas variáveis.
# Estudamos a função ```crosstab```, gráfico de dispersão, linha de tendência, correlação entre variáveis e mapa de calor. Puxa, foi muita coisa!
#
# Você conseguiur resolver os desafios que o Guilherme, o Thiago e a Vanessa deixaram pra vocês? Esperamos que sim porque hoje, vamos mergulhar na nossa penúltima aula!
#
# A primeira coisa que vamos fazer para essa aula é abrir a nossa outra base de dados. Para baixá-la vamos acessar o github para copiarmos o link do arquivo. No repositório nós temos dois arquivos: os dados_experimentos.zip e o dados_arquivos.csv. Nós vamos agora trabalhar com os dados_arquivos.csv.
#
# Vamos clicar com o botão esquerdo; assim que ele abrir, vamos clicar na opção "View raw" com o botão direito, e selecionar a opção "copiar endereço do link".
#
# Vamos importar o pandas(caso você não tenha importado ainda) para nos ajudar a ler essa base de dados, através do seguinte código:

# %%
## usaremos outro dataset: dados_resultados
## copiar link raw no github -> read_csv()

dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()

## cada coluna é um mecanismo de ação das drogas
## ou seja, esses dados nos trazem a relação do mecanismo de ação do alvo (enzima, proteína, etc) com a droga utilizada
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %% [markdown]
# Repare que ele já mostra pra gente o número de colunas: 207. Ou seja, é um dataset bem extenso.
#
# Vamos começar a analisar as colunas. A primeria coluna tem o nome de "id", o que nos remete a um identificador. Além disso, as seguintes colunas possuem nomes bem complexos. Não são nomes muito descritivos para quem não é da área.
#
# Com a ajuda da Vanessa, descobrimos que esses nomes remetem aos mecanismos de ação das drogas. Ou seja, esses dados nos trazem a relação do mecanismo de ação do alvo (enzima, proteína, etc) com a droga utilizada. Ela também explicou sobre os termos "agonista" e "antiagonista", que ativam o receptor e o bloqueiam, respectivamente.
#
# Nesse ponto a Vanessa nos explica numa apresentação como funciona a ligação do spike com o receptor e todo o procedimento de infecção nas nossas células.
#
# Agora já sabemos que cada coluna do nosso dataframe representa um mecanismo de ação. Olhando para nosso cabeçalho percebemos que temos praticamente todos os dados com o valor 0. Será que todos os dados da tabela tem esse valor? Vamos investigar!

# %%
## tem muito valor zero, né?
## vamos ver como é a distribuição dos dados da tabela

## começando com a coluna 'acetylcholine_receptor_agonist'

dados_resultados['acetylcholine_receptor_agonist'].unique()

## só tem 0 e 1 na coluna
## se o mecanismo de ação foi ativado, 1; se não foi, 0
# Out:
# array([0, 1])

# %% [markdown]
# Olha só! Nosso resultado foi um array entre 0 e 1. Se você quiser fazer um teste com todos os outros mecanismos de ação também encontrará o resultado entre 0 e 1. Mas por que isso acontece?
#
# Cada linha é o resultado do experimento da outra base de dados dos experimentos que trabalhamos. Quando um determinado mecanismo de ação é ativado ele é indicado como 1. Quando esse mecanismo de ação não é ativado ele é detectado como 0.
#
# Portanto, todo resultado que obtivermos o número 1, saberemos que ele foi ativado.
#
# Vamos fazer uma investigação agora que pode ser muito interessante para o cientista que está trabalhando nesse projeto: qual foi o mecanismo de ação que foi mais ativado?
#
# Vamos então fazer a soma das colunas, para saber qual vai ser o que apresenta mais o número 1. Mas antes vamos verificar se todas as minhas colunas possuem somente números ou se possuem strings também nelas, através desse código:

# %%
dados_resultados.info()

## dtypes: int64(206), object(1)
## essa coluna do tipo object certamente é a primeira ('id')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %% [markdown]
# Vimos que uma delas apresenta como resultado 1 objeto. Ou seja, não conseguiremos aplicar a função soma de forma direta.
#
# Vamos então fazer essa soma excluindo a coluna id, que possui dados diferentes de números em sua composição, da seguinte maneira:

# %%
## façamos a contagem dos mecanismos de ação que foram ativados
## para saber qual foi o mecanismo mais ativado, podemos somar cada coluna e o maior valor corresponderá ao mecanismo mais ativado

## duas formas de fazer:
  ## 1) somar apenas os valores numéricos (excluindo automaticamente a coluna id)
    ## dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
      ## select_dtypes('int64') --------> selecionar apenas as colunas do tipo 'int64'
      ## sum() -------------------------> somar as colunas
      ## sort_values(ascending=False) --> ordenar os valores, do maior para o menor (descending)


  ## 2) excluir a coluna id e somar o resto
    ## dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
      ## df.drop('id', axis=1) ---------> excluir a coluna 'id' do dataframe; axis=1 é o mesmo que dizer 'coluna' (por padrão nessa função, axis=0)
      ## sum() -------------------------> somar as colunas
      ## sort_values(ascending=False) --> ordenar os valores, do maior para o menor (descending)

contagem_moa = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moa


## pandas.DataFrame.select_dtypes https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.select_dtypes.html
## pandas.DataFrame.drop https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %% [markdown]
# Legal. No resultado há uma informação que nos chama a atenção: os inibidores, no topo do nosso resultado, são os que possuem maior quantidade de resultados positivos. Seria um ponto a se investigar.
#
# Então aqui vamos ter o nosso primeiro desafio da aula 4. Lembrando que todos os desafios estão no final desse notebook da aula.

# %% [markdown]
# Nós fizemos uma contagem para saber onde o mecanismo de ação obteve mais respostas; agora vamos fazer outros testes.
#
# Vamos verificar se a linha específica que vamos escolher foi ativada em algum momento. E, se ela foi ativada, quantas vezes isso ocorreu?
#
# Utilizaremos o seguinte código:

# %%
dados_resultados.drop('id', axis=1).sum(axis=1)

## sum(axis=1) soma as colunas e dá o resultado final por linha
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %% [markdown]
# E aqui temos o nosso resultado. Na primeira linha tivemos uma única ativação. Já na segunda não obtivemos nenhuma. Na terceira tivemos 3, e assim por diante. Nesse que tivemos a resposta como 0, precisaríamos saber se foi um controle, ou se realmente a droga não ativou nenhuma resposta.
#
# Aqui embaixo temos os nossos dados dos resultados:

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %% [markdown]
# E aqui temos a nossa base de dados:

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Na base de dados resultados não temos a informação que queremos, referente ao tratamento. Nós só temos a coluna tratamento na base de dados inteira.
#
# No tratamento só temos a coluna id, e os mecanismos de ação que foram ativados por aquela coluna. Então, agora, precisamos de alguma maneira, mesclar essas informações.
#
# Antes de fazer esse passo, de mesclar, vamos criar duas novas colunas na base de dados resultado. Vamos criar uma primeira coluna que vamos chamar de n_moa(número de moas ativos), que é justamente o que havíamos calculado anteriormente, dessa maneira:

# %%
## inserindo novas colunas:
  ## dados_resultados['n_moa'] ------> número de mecanismos de ação ativados por cada linha (int)
  ## dados_resultados['ativo_moa'] --> verificar se algum mecanismo foi ativado (bool)

dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)

# %% [markdown]
#  Vamos então verificar se a coluna apresenta resultados diferentes de 0; se for diferente de 0 ela retorna a mensagem 'true'; se for igual a 0 retorna 'false':

# %%
dados_resultados['n_moa'] != 0   ## se algum mecanismo de ação foi ativado, True; caso contrário, False (Series booleana)
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: n_moa, Length: 23814, dtype: bool

# %% [markdown]
# Ok, então o código para criarmos e visualizarmos as duas colunas é esse:

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %% [markdown]
# Para visualizarmos basta ir até as duas últimas colunas que elas estarão lá.

# %% [markdown]
# Agora que temos as duas colunas que queremos, vamos mesclar, ou então "mergear", as informações que queremos.
#
# Para isso vamos utilizar o merge do pandas, através desse código:

# %%
 dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on='id')

## pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on='id')
  ## onde o dado será mesclado? no dataframe dados (fica do lado esquerdo) -----------> left=dados  (fica do lado esquerdo)
  ## quais colunas eu vou mesclar? 'id', 'n_moa', 'ativo_moa' (fica do lado direito)--> right=dados_resultados[['id','n_moa', 'ativo_moa']]
  ## mas eles serão unidos por onde? pela coluna 'id', que é a mesma nos dois --------> on='id'

  ## importante: é necessário importar a coluna que vai unir os dois; tanto right quanto left precisam ter essa coluna

 dados_combinados.head()

 ## pandas.DataFrame.merge https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html
 ## Merge, join, concatenate and compare https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %% [markdown]
# Maravilha! Conseguimos agora a junção dos nossos dados de resultados com os dados de experimentos. Agora conseguimos responder a pergunta que fizemos anteriormente. No tratamento eu ativei algum moa?

# %% [markdown]
# Para fazer isso vamos utilizar o método:

# %%
dados_combinados.query('tratamento == "com_controle"' )['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %% [markdown]
# E obtivemos todas as respostas com o 'false'. Isso quer dizer que com controle não tivemos nenhuma resposta de algum mecanismo de ação.

# %% [markdown]
# Agora, será que algum tratamento que o paciente recebeu (com_droga, nesse caso) teve alguma substância que não ativou o mecanismo de ação? Vamos responder isso com a seguinte alteração no código anterior:

# %%
dados_combinados.query('tratamento == "com_droga"' )['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %% [markdown]
# Olha só, tivemos um resultado interessante. Vemos que 14447 tiveram mecanismos de ação, e aproximadamente 7500 não foram ativados.

# %% [markdown]
# Vamos fazer uma análise utilizando agora o boxplot, que gera uma imagem onde podemos identificar a mediana(linha central) e os quartis, entendendo assim como está a distribuição dos dados; dessa maneira vamos identificar, de forma visual, a comparação de categoria dos dados. Para isso vamos utilizar os seguintes códigos:

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y= 'g-0', x='composto', hue='ativo_moa')

# %% [markdown]
# Analisando os boxplots, percebemos que temos algumas categorias com a mediana próxima de 0; temos outra com a mediana próxima de 5 e a outra próxima de 2.
#
# É curioso observarmos também que o 3º boxplot, da esquerda para a direita, está bem concentrado; esse composto específico é na verdade o composto que nos indica que foi "com tratamento".
#
# Outro ponto interessante é que o último boxplot tem um comportamento muito semelhante ao 3º; provavelmente a droga não modificou tanto assim o gene 0.
#
# Agora é com você! Faça os desafios e nos encontramos na próxima aula.

# %% [markdown]
# ###Desafio 01: Encontrar o top 10, das ações do MOA (inibidor, agonista...)

# %%
contagem_moa.index.str.rsplit("_", n=1, expand=True)
# Out:
# MultiIndex([(                           'nfkb',  'inhibitor'),
#             (                     'proteasome',  'inhibitor'),
#             (                 'cyclooxygenase',  'inhibitor'),
#             (              'dopamine_receptor', 'antagonist'),
#             (             'serotonin_receptor', 'antagonist'),
#             (                            'dna',  'inhibitor'),
#             (             'glutamate_receptor', 'antagonist'),
#             (            'adrenergic_receptor', 'antagonist'),
#             (                            'cdk',  'inhibitor'),
#             (                           'egfr',  'inhibitor'),
#             ...
#             (                    'calcineurin',  'inhibitor'),
#             (                     'atm_kinase',  'inhibitor'),
#             (             'nicotinic_receptor',    'agonist'),
#             (              'retinoid_receptor', 'antagonist'),
#             (                 'antiarrhythmic',          nan),
#             (            'protein_phosphatase',  'inhibitor'),
#             (                      'autotaxin',  'inhibitor'),
#             (                       'diuretic',          nan),
#             (                          'erbb2',  'inhibitor'),
#             ('atp-sensitive_potassium_channel', 'antagonist')],
#            length=206)

# %%
contagem_moa.index = contagem_moa.index.str.rsplit("_", n=1, expand=True)

# %%
contagem_moa.head(10)
# Out:
# nfkb                 inhibitor     832
# proteasome           inhibitor     726
# cyclooxygenase       inhibitor     435
# dopamine_receptor    antagonist    424
# serotonin_receptor   antagonist    404
# dna                  inhibitor     402
# glutamate_receptor   antagonist    367
# adrenergic_receptor  antagonist    360
# cdk                  inhibitor     340
# egfr                 inhibitor     336
# dtype: int64

# %%
reset_moa = contagem_moa.reset_index()
print(reset_moa)
# Out:
#                              level_0     level_1    0
# 0                               nfkb   inhibitor  832
# 1                         proteasome   inhibitor  726
# 2                     cyclooxygenase   inhibitor  435
# 3                  dopamine_receptor  antagonist  424
# 4                 serotonin_receptor  antagonist  404
# ..                               ...         ...  ...
# 201              protein_phosphatase   inhibitor    6
# 202                        autotaxin   inhibitor    6
# 203                         diuretic         NaN    6
# 204                            erbb2   inhibitor    1
# 205  atp-sensitive_potassium_channel  antagonist    1
#
# [206 rows x 3 columns]

# %%
reset_moa.columns = ['moa', 'moa_activation', 'count']
contagem_moa_10 = reset_moa.groupby(by='moa_activation').sum().sort_values(by='count', ascending=False).head(10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,12))
plt.title("Tipos de mecanismos de ação mais ativados")

sns.set()
sns.barplot(y=contagem_moa_10.index, x='count', data=contagem_moa_10)

plt.show()

# %% [markdown]
# ###Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle

# %%
(dados_combinados['tratamento'] == "com_controle")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23809    False
# 23810    False
# 23811     True
# 23812    False
# 23813    False
# Name: tratamento, Length: 23814, dtype: bool

# %%
dados_combinados['eh_controle'] = (dados_combinados['tratamento'] == "com_controle")
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-99  n_moa  ativo_moa  eh_controle
# 0  id_000644bb2  com_droga     24   D1  ...  0.4176      1       True        False
# 1  id_000779bfc  com_droga     72   D1  ...  0.7371      0      False        False
# 2  id_000a6266a  com_droga     48   D1  ...  0.6931      3       True        False
# 3  id_0015fd391  com_droga     48   D1  ... -0.8154      0      False        False
# 4  id_001626bd3  com_droga     72   D2  ...  0.7125      1       True        False
#
# [5 rows x 880 columns]

# %% [markdown]
# ###Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72

# %%
dados_combinados['eh_24'] = (dados_combinados['tempo'] == 24)
dados_combinados['eh_48'] = (dados_combinados['tempo'] == 48)
dados_combinados['eh_78'] = (dados_combinados['tempo'] == 72)

dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... eh_controle  eh_24  eh_48  eh_78
# 0  id_000644bb2  com_droga     24   D1  ...       False   True  False  False
# 1  id_000779bfc  com_droga     72   D1  ...       False  False  False   True
# 2  id_000a6266a  com_droga     48   D1  ...       False  False   True  False
# 3  id_0015fd391  com_droga     48   D1  ...       False  False   True  False
# 4  id_001626bd3  com_droga     72   D2  ...       False  False  False   True
#
# [5 rows x 883 columns]

# %% [markdown]
# ###Desafio 04: Estudar sobre combinações de DF https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ###Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (Escolher uma droga e comparar com controle)

# %%
## compararemos controle e a droga mais comum

droga_controle = dados_combinados.composto.value_counts().index[:2]
droga_controle

## controle: cacb2b860
## droga mais comum: 87d714366
# Out:
# Index(['cacb2b860', '87d714366'], dtype='object')

# %%
dados_combinados.query('composto in @droga_controle')  ## query apenas com os dois elementos a serem comparados
# Out:
#                  id    tratamento  tempo dose  ... eh_controle  eh_24  eh_48  eh_78
# 16     id_002fb9c19     com_droga     48   D1  ...       False  False   True  False
# 25     id_0054388ec  com_controle     48   D1  ...        True  False   True  False
# 38     id_0079af0fb  com_controle     24   D1  ...        True   True  False  False
# 40     id_007bfbb91  com_controle     24   D2  ...        True   True  False  False
# 47     id_008a986b7  com_controle     48   D2  ...        True  False   True  False
# ...             ...           ...    ...  ...  ...         ...    ...    ...    ...
# 23776  id_ff9d0a022     com_droga     24   D2  ...       False   True  False  False
# 23791  id_ffd1fd119     com_droga     72   D2  ...       False  False  False   True
# 23793  id_ffd26f361  com_controle     48   D2  ...        True  False   True  False
# 23802  id_fff3976bd     com_droga     24   D1  ...       False   True  False  False
# 23811  id_fffc1c3f4  com_controle     48   D2  ...        True  False   True  False
#
# [2584 rows x 883 columns]

# %%
ax = sns.catplot(kind='count', data=dados_combinados.query('composto in @droga_controle'), x='composto', col='tempo',row='dose')

plt.show()

# %% [markdown]
# ###Desafio 06: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA

# %% [markdown]
# ###Desafio 07: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa MOAs diferentes

# %% [markdown]
# ###Desafio 08: Resumo do que você aprendeu com os dados
